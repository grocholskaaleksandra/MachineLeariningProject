# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750 entries, 0 to 3749
# Columns: 10000 entries, 0 to 9999
# dtypes: float64(10000)
# memory usage: 286.1 MB
# number of duplicate rows:  (0, 10000)
#               0            1              2              3             4     \
# count  3750.000000  3750.000000    3750.000000    3750.000000   3750.000000
# mean     30.644135     9.080955     169.679419     811.083532   -186.008805
# std     286.172414   213.166659   43665.003613   57123.457110  21942.466227
# min    -989.450000  -859.922000 -163336.428000 -243844.632000 -77566.109000
# 25%    -163.781750  -135.343500  -29284.119500  -38028.429000 -14426.799500
# 50%      35.478500     2.680500    1181.698500     980.588000   -154.835000
# 75%     215.780500   156.095750   29630.914500   40561.960250  14515.833000
# max    1224.394000   722.868000  177744.241000  215372.854000  86287.955000
#
#               5            6            7            8            9     ...  \
# ...

# %%
import pandas as pd
import numpy as np

# %%
def upsamling_minority_class(features, target):
    """
    Upsampling minority class to get balanced data set.

    :param target:
    :param features:
    :return:
    """
    print('Upsampling minority class')
    # indices of each class
    minor_class = np.where(target == -1)[0]
    major_class = np.where(target == 1)[0]

    n_minor_class = len(minor_class)
    n_major_class = len(major_class)
    print(f'Len of minor class is: {n_minor_class} \n and major class: {n_major_class}' )
    print("")

    # randomly choosing observation from minority class and duplicate it
    minor_class_upsampled = np.random.choice(minor_class, size=n_major_class, replace=True)

    # join together target vectors
    upsampled_target = np.concatenate((target[minor_class_upsampled], target[major_class]))

    # join together features vector
    upsampled_features = np.vstack((features[minor_class_upsampled, :], features[major_class, :]))
    return upsampled_features, upsampled_target

# %%
upsampled_X, upsampled_y = upsamling_minority_class(X_train_standarized, trainy.values)
# Out:
# Upsampling minority class
# Len of minor class is: 269
#  and major class: 2356
# [[ 0.18612781 -1.55542849 -0.88651157 ...  0.12709021 -0.85409464
#    0.70998786]
#  [-0.87452684  0.26081774 -0.78732114 ... -0.1835198   0.60817541
#    2.24424879]
#  [ 0.30788809 -1.064302   -1.66822904 ... -0.91618626  1.40949825
#   -1.07990625]
#  ...
#  [-1.14320145  0.56904276 -1.47643668 ...  0.25792784 -0.56935511
#    0.78040154]
#  [ 0.4460194  -0.91633857  0.03942784 ...  0.54326797  0.52572273
#    1.37728403]
#  [ 1.00966889  0.51639351 -0.3147714  ...  0.53914822  0.11559925
#    0.79314527]]
