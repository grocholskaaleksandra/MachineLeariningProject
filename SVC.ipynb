# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750 entries, 0 to 3749
# Columns: 10000 entries, 0 to 9999
# dtypes: float64(10000)
# memory usage: 286.1 MB
# number of duplicate rows:  (0, 10000)
#               0            1              2              3             4     \
# count  3750.000000  3750.000000    3750.000000    3750.000000   3750.000000
# mean     30.644135     9.080955     169.679419     811.083532   -186.008805
# std     286.172414   213.166659   43665.003613   57123.457110  21942.466227
# min    -989.450000  -859.922000 -163336.428000 -243844.632000 -77566.109000
# 25%    -163.781750  -135.343500  -29284.119500  -38028.429000 -14426.799500
# 50%      35.478500     2.680500    1181.698500     980.588000   -154.835000
# 75%     215.780500   156.095750   29630.914500   40561.960250  14515.833000
# max    1224.394000   722.868000  177744.241000  215372.854000  86287.955000
#
#               5            6            7            8            9     ...  \
# ...

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
SVCclf = SVC(C=5, gamma='auto', kernel='linear')
SVCclf.fit(trainX, trainy)
pred_SVCclf = SVCclf.predict(testX)
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
df = pd.DataFrame(pred_SVCclf)

# %%
df.value_counts()
# Out:
#  1    1104
# -1      21
# dtype: int64

# %%
print(classification_report(testy, pred_SVCclf))
print(confusion_matrix(testy, pred_SVCclf))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.10      0.02      0.03       106
#            1       0.91      0.98      0.94      1019
#
#     accuracy                           0.89      1125
#    macro avg       0.50      0.50      0.49      1125
# weighted avg       0.83      0.89      0.86      1125
#
# [[   2  104]
#  [  19 1000]]

# %%
neigh = KNeighborsClassifier(n_neighbors=11)
neigh.fit(trainX, trainy)
pred_neigh = neigh.predict(testX)
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
neigh.score(trainX, trainy, sample_weight=None)
# Out:
# 0.964952380952381

# %%
print(classification_report(testy, pred_neigh))
print(confusion_matrix(testy, pred_neigh))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.82      0.72      0.76       106
#            1       0.97      0.98      0.98      1019
#
#     accuracy                           0.96      1125
#    macro avg       0.89      0.85      0.87      1125
# weighted avg       0.96      0.96      0.96      1125
#
# [[  76   30]
#  [  17 1002]]

# %%
pred_neigh
# Out:
# array([-1,  1,  1, ..., -1,  1,  1], dtype=int64)

# %%
testy
# Out:
#       0
# 2148 -1
# 1044  1
# 3318  1
# 439   1
# 3515  1
# ...  ..
# 1459  1
# 1789  1
# 3662 -1
# 1151  1
# 942   1
#
# [1125 rows x 1 columns]
