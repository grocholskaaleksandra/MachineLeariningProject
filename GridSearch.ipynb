# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750 entries, 0 to 3749
# Columns: 10000 entries, 0 to 9999
# dtypes: float64(10000)
# memory usage: 286.1 MB
# number of duplicate rows:  (0, 10000)
#               0            1              2              3             4     \
# count  3750.000000  3750.000000    3750.000000    3750.000000   3750.000000
# mean     30.644135     9.080955     169.679419     811.083532   -186.008805
# std     286.172414   213.166659   43665.003613   57123.457110  21942.466227
# min    -989.450000  -859.922000 -163336.428000 -243844.632000 -77566.109000
# 25%    -163.781750  -135.343500  -29284.119500  -38028.429000 -14426.799500
# 50%      35.478500     2.680500    1181.698500     980.588000   -154.835000
# 75%     215.780500   156.095750   29630.914500   40561.960250  14515.833000
# max    1224.394000   722.868000  177744.241000  215372.854000  86287.955000
#
#               5            6            7            8            9     ...  \
# ...

# %%
# %run Upsampling.ipynb
# Out:
# Upsampling minority class
# Len of minor class is: 267
#  and major class: 2358

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import KernelPCA

# %%
svc = SVC()
C = np.logspace(0, 4, 10)
kernel = ['linear', 'rbf', 'poly']
gamma = ['scale', 'auto']
class_weight = [None, 'balanced']
max_iter = [1]

pipe = Pipeline([('StandardScaler', StandardScaler()), ('PCA', PCA(0.95)), ("classifier", svc)])
hyperparameters = dict(C=C, class_weight=class_weight, gamma=gamma, kernel=kernel, max_iter=max_iter)

# %%
gridsearch = GridSearchCV(svc, hyperparameters, cv=5, verbose=1, n_jobs=-1)

# %%
display("HYPERPARAMETERS")
display(hyperparameters)

display("SVC PARAMETERS")
display(svc.get_params().keys())

display("GRIDSEARCH STEPS")
display(gridsearch)
# Out:
# 'SVC PARAMETERS'
# dict_keys(['C', 'break_ties', 'cache_size', 'class_weight', 'coef0', 'decision_function_shape', 'degree', 'gamma', 'kernel', 'max_iter', 'probability', 'random_state', 'shrinking', 'tol', 'verbose'])
# 'GRIDSEARCH STEPS'
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04]),
#                          'class_weight': [None, 'balanced'],
#                          'gamma': ['scale', 'balanced'],
#                          'kernel': ['linear', 'rbf', 'poly'], 'max_iter': [1]},
#              verbose=1)

# %%
best_model = gridsearch.fit(upsampled_X, np.ravel(upsampled_y.T))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# C:\Miniconda\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.50466641 0.48154982 0.49894045        nan        nan        nan
#  0.50466641 0.50000157 0.50063717        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
#  0.50466641 0.50466641 0.50212067        nan        nan        nan
# ...

# %%
best_model.best_score_
# Out:
# 0.504666409044341

# %%
best_model.best_params_
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': 1}
