# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750 entries, 0 to 3749
# Columns: 10000 entries, 0 to 9999
# dtypes: float64(10000)
# memory usage: 286.1 MB
# number of duplicate rows:  (0, 10000)
#               0            1              2              3             4     \
# count  3750.000000  3750.000000    3750.000000    3750.000000   3750.000000
# mean     30.644135     9.080955     169.679419     811.083532   -186.008805
# std     286.172414   213.166659   43665.003613   57123.457110  21942.466227
# min    -989.450000  -859.922000 -163336.428000 -243844.632000 -77566.109000
# 25%    -163.781750  -135.343500  -29284.119500  -38028.429000 -14426.799500
# 50%      35.478500     2.680500    1181.698500     980.588000   -154.835000
# 75%     215.780500   156.095750   29630.914500   40561.960250  14515.833000
# max    1224.394000   722.868000  177744.241000  215372.854000  86287.955000
#
#               5            6            7            8            9     ...  \
# ...

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
SVCclf = SVC(random_state=42)
SVCclf.fit(X_train_standarized, trainy.values.ravel())
score_SVCclf = SVCclf.score(trainX, trainy, sample_weight=None)
print("Score for SVC: ", score_SVCclf)
plot_confusion_matrix(SVCclf, 
                     X_test_standarized,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
# Out:
# Score for SVC:  0.8975238095238095

# %%
#TUTAJ DOLOZYC TAKIE PARAMETRY DO SVC JAK WYJDA U MIKOLAJA W GRIDSEARCH - JUST A PLACEHOLDER

SVCclf_adjusted = SVC(C=5, gamma='auto', kernel='linear')
SVCclf_adjusted.fit(X_train_standarized, trainy.values.ravel())
score_SVCclf_adjusted = SVCclf_adjusted.score(trainX, trainy, sample_weight=None)
print("Score for SVC with values selected by GridSearch: ", score_SVCclf_adjusted)
plot_confusion_matrix(SVCclf_adjusted, 
                     X_test_standarized,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
# Out:
# Score for SVC with values selected by GridSearch:  0.7634285714285715

# %%
scaler = StandardScaler().fit(trainX)
X_train_std = scaler.transform(trainX)
X_test_std = scaler.transform(testX)

# %%
n_neighbors = list(range(1, 11))
test_score = []
train_score = []

# %%
for i in n_neighbors:
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train_std, trainy.values.ravel())
    test_score.append(round(model.score(X=X_train_std, y=trainy), 3))
    train_score.append(round(model.score(X=X_test_std, y=testy), 3))

# %%
plt.figure(figsize=(10,5))

sns.lineplot(x=n_neighbors, y=test_score, label="Test data")
sns.lineplot(x=n_neighbors, y=train_score, label="Train data")

plt.title("Number of neighbors and score")
plt.legend()
plt.grid();

# %%
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(trainX, trainy.values.ravel())
score_neigh = neigh.score(trainX, trainy.values.ravel(), sample_weight=None)
print("Score for KNeighbours Classifier: ", score_neigh)
plot_confusion_matrix(neigh, 
                     testX,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
# Out:
# Score for KNeighbours Classifier:  0.9687619047619047
