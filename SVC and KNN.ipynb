# %%
# %run GridSearch.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750 entries, 0 to 3749
# Columns: 10000 entries, 0 to 9999
# dtypes: float64(10000)
# memory usage: 286.1 MB
# number of duplicate rows:  (0, 10000)
#               0            1              2              3             4     \
# count  3750.000000  3750.000000    3750.000000    3750.000000   3750.000000
# mean     30.644135     9.080955     169.679419     811.083532   -186.008805
# std     286.172414   213.166659   43665.003613   57123.457110  21942.466227
# min    -989.450000  -859.922000 -163336.428000 -243844.632000 -77566.109000
# 25%    -163.781750  -135.343500  -29284.119500  -38028.429000 -14426.799500
# 50%      35.478500     2.680500    1181.698500     980.588000   -154.835000
# 75%     215.780500   156.095750   29630.914500   40561.960250  14515.833000
# max    1224.394000   722.868000  177744.241000  215372.854000  86287.955000
#
#               5            6            7            8            9     ...  \
# ...

# %%
scaler = StandardScaler().fit(trainX)
X_train_std = scaler.transform(trainX)
X_test_std = scaler.transform(testX)

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.plotting import plot_decision_regions
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
#SVC on standarized data without model selected by GridSearch

SVCclf = SVC(random_state=42, class_weight='balanced')
SVCclf.fit(X_train_std, trainy.values.ravel())
score_SVCclf = SVCclf.score(X_train_std, trainy, sample_weight=None)
print("Score for SVC: ", score_SVCclf)
plot_confusion_matrix(SVCclf, 
                     X_test_std,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
pred_SVCclf = SVCclf.predict(X_test_std)
print(classification_report(testy, pred_SVCclf))
# Out:
# Score for SVC:  1.0
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       106
#            1       0.91      1.00      0.95      1019
#
#     accuracy                           0.91      1125
#    macro avg       0.45      0.50      0.48      1125
# weighted avg       0.82      0.91      0.86      1125
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
pca = PCA(n_components = 2)
X_train = pca.fit_transform(X_train_std)
SVCclf.fit(X_train, trainy.values.ravel())
plot_decision_regions(X_train, trainy.values.ravel(), clf=SVCclf, legend=2)
plt.xlabel('X_train_std')
plt.ylabel('trainy')
plt.title('SVCclf')
plt.show()

# %%
#SVC on standarized data with model selected by GridSearch

SVCclf_adjusted = SVC(C=2.7825594022071245, gamma='scale', kernel='poly', class_weight=None, max_iter=1)
SVCclf_adjusted.fit(X_train_std, trainy.values.ravel())
score_SVCclf_adjusted = SVCclf_adjusted.score(X_train_std, trainy, sample_weight=None)
print("Score for SVC with values selected by GridSearch: ", score_SVCclf_adjusted)
plot_confusion_matrix(SVCclf_adjusted, 
                     X_test_std,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
pred_SVCclf_adjusted = SVCclf_adjusted.predict(X_test_std)
print(classification_report(testy, pred_SVCclf_adjusted))
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# Score for SVC with values selected by GridSearch:  0.8979047619047619
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       106
#            1       0.91      1.00      0.95      1019
#
#     accuracy                           0.91      1125
#    macro avg       0.45      0.50      0.48      1125
# weighted avg       0.82      0.91      0.86      1125
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
pca = PCA(n_components = 2)
X_train2 = pca.fit_transform(X_train_std)
SVCclf_adjusted.fit(X_train2, trainy.values.ravel())
plot_decision_regions(X_train2, trainy.values.ravel(), clf=SVCclf_adjusted, legend=2)
# Adding axes annotations
plt.xlabel('X_train_std')
plt.ylabel('trainy')
plt.title('SVCclf_adjusted')
plt.show()
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'

# %%
#SVC on upsampled data with model selected by GridSearch

SVCclf_upsampled = SVC(C=1.0, gamma='scale', kernel='rbf', class_weight=None, max_iter=1)
SVCclf_upsampled.fit(upsampled_X, np.ravel(upsampled_y.T))
score_SVCclf_upsampled = SVCclf_upsampled.score(upsampled_X, upsampled_y, sample_weight=None)
print("Score for SVC with values selected by GridSearch: ", SVCclf_upsampled)
plot_confusion_matrix(SVCclf_upsampled, 
                     X_test_std,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
pred_SVCclf_upsampled = SVCclf_upsampled.predict(X_test_std)
print(classification_report(testy, pred_SVCclf_upsampled))
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# Score for SVC with values selected by GridSearch:  SVC(max_iter=1)
#               precision    recall  f1-score   support
#
#           -1       0.10      0.56      0.16       106
#            1       0.91      0.45      0.60      1019
#
#     accuracy                           0.46      1125
#    macro avg       0.50      0.50      0.38      1125
# weighted avg       0.83      0.46      0.56      1125

# %%
pca = PCA(n_components = 2)
X_train2 = pca.fit_transform(X_train_std)
SVCclf_upsampled.fit(X_train2, trainy.values.ravel())
plot_decision_regions(X_train2, trainy.values.ravel(), clf=SVCclf_upsampled, legend=2)
# Adding axes annotations
plt.xlabel('upsampled_X')
plt.ylabel('trainy')
plt.title('Pipelne Upsampled SVC')
plt.show()
# Out:
# C:\Users\Wladkowie\anaconda3\envs\Machine_Learning_intro\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'

# %%
n_neighbors = list(range(1, 11))
test_score = []
train_score = []

# %%
for i in n_neighbors:
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train_std, trainy.values.ravel())
    test_score.append(round(model.score(X=X_train_std, y=trainy), 3))
    train_score.append(round(model.score(X=X_test_std, y=testy), 3))

# %%
plt.figure(figsize=(10,5))

sns.lineplot(x=n_neighbors, y=test_score, label="Test data")
sns.lineplot(x=n_neighbors, y=train_score, label="Train data")

plt.title("Number of neighbors and score")
plt.legend()
plt.grid();

# %%
#KNN on upsampled data

neigh2 = KNeighborsClassifier(n_neighbors=5)
neigh2.fit(upsampled_X, np.ravel(upsampled_y.T))
score_neigh2 = neigh2.score(upsampled_X, np.ravel(upsampled_y.T), sample_weight=None)
print("Score for KNeighbours Classifier: ", score_neigh2)
plot_confusion_matrix(neigh2, 
                     testX,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
pred_neigh = neigh2.predict(testX)
print(classification_report(testy, pred_neigh))
# Out:
# Score for KNeighbours Classifier:  0.9142614601018676
#               precision    recall  f1-score   support
#
#           -1       0.09      0.05      0.06       106
#            1       0.91      0.95      0.93      1019
#
#     accuracy                           0.87      1125
#    macro avg       0.50      0.50      0.50      1125
# weighted avg       0.83      0.87      0.85      1125

# %%
pca = PCA(n_components = 2)
X_train2 = pca.fit_transform(X_train_std)
neigh2.fit(X_train2, trainy.values.ravel())
plot_decision_regions(X_train2, trainy.values.ravel(), clf=neigh2, legend=2)
# Adding axes annotations
plt.xlabel('upsampled_X')
plt.ylabel('trainy')
plt.title('neigh2')
plt.show()

# %%
#KNN 

neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(trainX, trainy.values.ravel())
score_neigh = neigh.score(trainX, trainy.values.ravel(), sample_weight=None)
print("Score for KNeighbours Classifier: ", score_neigh)
plot_confusion_matrix(neigh, 
                     testX,
                     testy, 
                     values_format='d', 
                     display_labels=["Negative", "Positive"])
pred_neigh = neigh.predict(testX)
print(classification_report(testy, pred_neigh))
# Out:
# Score for KNeighbours Classifier:  0.9687619047619047
#               precision    recall  f1-score   support
#
#           -1       0.82      0.73      0.77       106
#            1       0.97      0.98      0.98      1019
#
#     accuracy                           0.96      1125
#    macro avg       0.90      0.85      0.87      1125
# weighted avg       0.96      0.96      0.96      1125

# %%
pca = PCA(n_components = 2)
X_train2 = pca.fit_transform(X_train_std)
neigh.fit(X_train2, trainy.values.ravel())
plot_decision_regions(X_train2, trainy.values.ravel(), clf=neigh, legend=2)
# Adding axes annotations
plt.xlabel('X_train_std')
plt.ylabel('trainy')
plt.title('neigh')
plt.show()

# %%
neigh.fit(trainX, trainy.values.ravel())
pred_final_model = neigh.predict(test_data)

# %%
np.savetxt("test_labels.csv", pred_final_model, delimiter=",")
